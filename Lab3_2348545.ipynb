# %% [markdown]
# <a href="https://colab.research.google.com/github/sahay-46/AML/blob/main/Lab3_2348545.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing dataset
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Program_3a_Dataset.csv')
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
#checking null values
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#assigning dependent and independent variables
X=data[['age','duration','campaign']]
Y=data['y']

# %%
#standardizing independent variables
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X[X.columns]=sc.fit_transform(X)
X.head()
# Out:
# <ipython-input-8-7141371b7e2b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[X.columns]=sc.fit_transform(X)
#         age  duration  campaign
# 0  1.533034  0.010471 -0.565922
# 1  1.628993 -0.421501 -0.565922
# 2 -0.290186 -0.124520 -0.565922
# 3 -0.002309 -0.413787 -0.565922
# 4  1.533034  0.187888 -0.565922

# %%
#splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, stratify=Y, random_state=2)

# %%
#fitting logistic model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
#calculating accuracy for training data
from sklearn.metrics import accuracy_score
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.8935520793590233

# %%
#calculating accuracy for testing data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.8921259205308731

# %%
#classification report
from sklearn.metrics import classification_report
print(classification_report(Y_test, X_test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.90      0.99      0.94     10965
#          yes       0.58      0.15      0.24      1392
#
#     accuracy                           0.89     12357
#    macro avg       0.74      0.57      0.59     12357
# weighted avg       0.87      0.89      0.86     12357

# %%
#Confusion matrix for the same
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y_test, X_test_prediction)
confusion_matrix
# Out:
# array([[10814,   151],
#        [ 1182,   210]])

# %% [markdown]
# Accuracy is nearly 90% but False negative is too much. Therefore, we cannot rely on the model completely.

# %%
#importing dataset
data1=pd.read_csv('/content/drive/MyDrive/Program_3b_dataset.csv')
data1.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
#checking for null values
data1.isnull().sum()
# Out:
# variance    0
# skewness    0
# curtosis    0
# entropy     0
# class       0
# dtype: int64

# %%
#assigning dependent and independent variables
X=data1.drop(columns='class',axis=1)
Y=data1['class']

# %%
#standardizing independent variables
X[X.columns]=sc.fit_transform(X)
X.head()
# Out:
#    variance  skewness  curtosis   entropy
# 0  1.121806  1.149455 -0.975970  0.354561
# 1  1.447066  1.064453 -0.895036 -0.128767
# 2  1.207810 -0.777352  0.122218  0.618073
# 3  1.063742  1.295478 -1.255397 -1.144029
# 4 -0.036772 -1.087038  0.736730  0.096587

# %%
#splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, stratify=Y, random_state=2)

# %%
#fitting logistic model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
#calculating accuracy for training data
from sklearn.metrics import accuracy_score
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.9802083333333333

# %%
#calculating accuracy for testing data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.9830097087378641

# %%
#classification report
from sklearn.metrics import classification_report
print(classification_report(Y_test, X_test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       229
#            1       0.97      0.99      0.98       183
#
#     accuracy                           0.98       412
#    macro avg       0.98      0.98      0.98       412
# weighted avg       0.98      0.98      0.98       412

# %%
#Confusion matrix for the same
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y_test, X_test_prediction)
confusion_matrix
# Out:
# array([[224,   5],
#        [  2, 181]])

# %% [markdown]
# The model accuracy is good and FN and FP are also low. Therefore, we can rely on the model.
